# %%
from backend.services.prompt_template import PromptTemplate
from backend.services.request_llm import RequestLLM

# %%
prompt_template = PromptTemplate()
request = RequestLLM()

prompt = prompt_template.lawyers("Apakah karyawan berhak mendapatkan pesangon jika mereka diberhentikan oleh perusahaan?")

# %%
print(prompt)
# Out:
# System:
#         Anda adalah seorang ahli hukum yang sangat cerdas dan berpengetahuan luas tentang undang-undang di Indonesia. Anda akan menjawab pertanyaan terkait hukum dan undang-undang dengan memberikan penjelasan yang jelas dan referensi yang relevan.
#
#         Instruksi:
#         Pertanyaan: Jawablah pertanyaan yang diberikan dengan ringkas dan jelas.
#         Penjelasan: Jelaskan prinsip hukum atau undang-undang yang berlaku.
#         Sumber: Berikan referensi dari undang-undang, yurisprudensi, atau literatur hukum yang relevan.
#         Contoh Pertanyaan:
#         Pertanyaan: Apakah karyawan berhak mendapatkan pesangon jika mereka diberhentikan oleh perusahaan?
#
#         Tugas Anda:
#         Jawaban:
#         <Jawablah pertanyaan dengan tegas.>
#         Penjelasan:
#         <Berikan penjelasan terkait hak karyawan atas pesangon berdasarkan undang-undang yang berlaku.>
#         Sumber:
#         Berikan referensi dari undang-undang yang relevan.
# ...

# %%
res = request.request_generate(prompt=prompt)
# Out:
# No references added, getting references

# %%
res
# Out:
# Response(response='Jawaban:\nYa, karyawan berhak mendapatkan pesangon jika mereka diberhentikan oleh perusahaan.\n\nPenjelasan:\nMenurut undang-undang yang berlaku, dalam hal terjadi pemutusan hubungan kerja, pengusaha diwajibkan membayar uang pesangon, uang penghargaan masa kerja, dan uang penggantian hak yang seharusnya diterima oleh karyawan. Besaran uang pesangon yang diberikan tergantung pada masa kerja karyawan di perusahaan tersebut.\n\nSumber:\nUndang-Undang No. 6 Tahun 2023, Pasal 156 ayat (1) dan ayat (2).', source_nodes=[NodeWithScore(node=TextNode(id_='2a594283-3603-4489-b33d-2df57541aef5', embedding=[0.00138904771, -0.0231411066, -0.00220538024, 0.0388146937, 0.0126646953, 0.0159881525, 0.0224299151, 0.0478687212, -0.039033521, 0.0192158725, -0.0148256263, -0.00699225254, 0.00564167043, -0.0364349335, -0.0179849621, 0.00335935829, -0.0159608, 0.00712560071, -0.017861871, 0.00878732931, -0.0257807244, 0.0124663822, -0.0194483772, 0.00288750953, 0.0174105372, 0.021267388, 
# ...

# %%
print(res)
# Out:
# Jawaban:
# Ya, karyawan berhak mendapatkan pesangon jika mereka diberhentikan oleh perusahaan.
#
# Penjelasan:
# Menurut undang-undang yang berlaku, dalam hal terjadi pemutusan hubungan kerja, pengusaha diwajibkan membayar uang pesangon, uang penghargaan masa kerja, dan uang penggantian hak yang seharusnya diterima oleh karyawan. Besaran uang pesangon yang diberikan tergantung pada masa kerja karyawan di perusahaan tersebut.
#
# Sumber:
# Undang-Undang No. 6 Tahun 2023, Pasal 156 ayat (1) dan ayat (2).
